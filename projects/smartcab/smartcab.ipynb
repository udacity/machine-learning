# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Reinforcement Learning
# ## Project: Train a Smartcab to Drive
#
# Welcome to the fourth project of the Machine Learning Engineer Nanodegree! In this notebook, template code has already been provided for you to aid in your analysis of the *Smartcab* and your implemented learning algorithm. You will not need to modify the included code beyond what is requested. There will be questions that you must answer which relate to the project and the visualizations provided in the notebook. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide in `agent.py`.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %%
# %matplotlib inline
import plotting as plt
plt.plot_trials('trials_2016-07-08_13-44-06.csv')

# %% [markdown]
# ## Implement a Basic Driving Agent
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT

# %% [markdown]
# ### Implementation - Moving in the Environment

# %% [markdown]
# ### Visualize Logging Data
# Run code below to produce graph -- answer for question 1

# %%
# Visualization Code

# %% [markdown]
# ### Question 1 - Analysis of Initial Simulation Results
# Observe the 100 trials your smartcab performs during the simulation when no input information is considered and random actions are taken. *How many of those trials resulted in a success of reaching the destination? Did any trials produce a positive net reward?*

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 2 - Observations of Initial Behavior
# ??????

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## Inform the Driving Agent
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT

# %% [markdown]
# ### Question 3 - Identify States
# *What states have you identified that are appropriate for modeling the smartcab and environment? For each state, provide discussion for why you think it is appropriate to be included for the Q-Learner for this problem.*

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 4 - State Space
# *Given the actions available to the driving agent and your states defined above, how many state-action pairs in total exist for the smartcab environment? Does this number seem reasonable given that the goal of Q-Learning is to learn and make informed decisions about each state? Why or why not?*
# **Hint:** The driving agent can choose from one of four actions: `'Forward'`, `'Left'`, `'Right'`, and `'None'`.

# %% [markdown]
# ### Implementation - Update Driving Agent State
# Instructions regarding making the driving agent update its state after completing an action.

# %% [markdown]
# ## Implement a Q-Learning Driving Agent
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT

# %% [markdown]
# ### Implementation - Q-Learning
# Instructions regarding the implementation of the Q-learning algorithm and what needs needs to be done.

# %% [markdown]
# ### Visualize Logging Data
# Run code below to produce graph -- two questions

# %%
# Visualization code

# %% [markdown]
# ### Question 5 - Analysis of Q-Learning Simulation Results
# Observe the 100 trials your smartcab performs during the simulation when input is now considered and your agent has learned the best action to take at each state. *How many of those trials resulted in a success of reaching the destination? How many trials resulted in a postive net reward?*

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 6 - Observations of Q-Learning Behavior
# ????????????

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## Improve the Q-Learning Driving Agent
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT
# FILLER TEXT

# %% [markdown]
# ### Implementation - Parameter Tuning
# Discuss tuning the parameters for the Bellman Equation and producing four separate logging files

# %% [markdown]
# ### Visualize Logging Data
# Here we will load four separate log files that contain the different parameter stuff

# %%
# Visualization code
#Tester

# %% [markdown]
# ### Question 7 - Tuning the Learning Rate and Discount Factor
# Choose at least two values for both the learning rate and the discount factor and run a simulation for each combination of these values. For each simulation, observe the 100 trials your smartcab performs with the given learning rate and discount factor. *How many trials resulted in a success of reaching the destination? How many trials resulted in a positive net reward? Which combination of parameter seems to give the best results?*

# %% [markdown]
# ### Implementation - Model Optimization
# Final parameter decision

# %% [markdown]
# ### Visualize Logging Data
# Here we will load the final logging data

# %%
# Visualization Code

# %% [markdown]
# ### Question 8 - Safety and Efficiency
# For your final, improved Q-Learning driving agent, observe the 110 trials your smartcab performs — 100 for the initial Q-Learning, and then 10 for testing the model. *With the 10 testing trials, how many trials resulted in a success of reaching the destination? How many trials resulted in a positive net reward? What is the average net reward across 10 trials?*

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 9 - Observations of Improved Q-Learning Behavior
# ????????????

# %% [markdown]
# **Answer:**
